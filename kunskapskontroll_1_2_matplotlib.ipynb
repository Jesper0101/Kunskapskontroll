# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
#Plotting can be done in the Object-oriented way or the pyplot/Matlab approach
#Generally it's recommended to use the object-oriented way

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
#Figure is seen as the whole figure and is genarlly seen as a "canvas"
#Axes is the part of the "canvas" the plot is attached too
#Axis sets the scale and limits and genarates ticks which marks the marks on the Axis
#And ticklabels which labels the stings labelling the ticks
#Artist is basically everything visble on a figure, the figure it self, Axesis and Axisies. Most artists are tied to an Axes

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
#When plotting in Matplotlib you use numpy arrays as input or objects that then can be 
#transformed to numpy array with function numpy.asarray

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
#Import of packeges
import numpy as np
import matplotlib.pyplot as plt

#This is the Object-oriented way (preferred method)
#data point evenly space between -4 to 4
x = np.linspace(-4, 4, 100)
y = x**2

#This is the Object-oriented way (preferred method)
#creating a figure and axes and then call upon our data point
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("Plot Title")
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')


#This is the pyplot method (not the preferred method)
#This functions like the above method and is faster
#plt.plot(x, y)
# Out:
# Text(0, 0.5, 'Y Label')

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
#Creating a figure and axes
fig, axs = plt.subplots(1,2)
#Calling upon our random data using scatter
axs[0].scatter(random_data_x, random_data_y)
#Sets title for our scatter plot
axs[0].set_title('Scatter Plot')
#Calling upon our fruit data and using bars
axs[1].bar(names, values)
# Out:
# <BarContainer object of 5 artists>
